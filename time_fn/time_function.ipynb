# %%
from bmcs_matmod.matmod.ms1.time_function import TimeFunction
import bmcs_utils.api as bu

eps = [0, -0.002745, -0.0016, -0.0047, -0.0025, -0.0065, -0.003, -0.0085, -0.004, -0.01]

tf = TimeFunction(n_i=0, values=eps)

bu.InteractiveWindow(tf).interact()
# Out:
# VBox(children=(Output(), Tab(children=(GridBox(children=(IntSlider(value=0, continuous_update=False, descripti…
