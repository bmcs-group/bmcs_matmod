# %% [markdown]
# # GSM Framework Demonstration Notebooks
#
# This collection of notebooks provides a comprehensive introduction to the **Generalized Standard Material (GSM) framework** for material modeling. The GSM framework offers a thermodynamically consistent approach to modeling complex material behaviors including viscoelasticity, damage, and plasticity.
#
# ## Overview
#
# The notebooks are organized to provide both theoretical background and practical demonstrations of the GSM framework capabilities. They cover material models of increasing complexity and various loading scenarios.

# %%
# Import required libraries for rendering content
from IPython.display import display, Markdown, HTML

# %%
# Define notebook information structure
notebooks = [
    {
        "filename": "01_gsm_ve.ipynb",
        "title": "GSM-VE: Visco-elastic Model",
        "description": "Introduction to the basic visco-elastic material model using the GSM framework.\n" +
                      "Demonstrates linear strain loading, creep behavior, and cyclic loading with relaxation.\n" +
                      "Shows both strain-controlled and stress-controlled simulations."
    },
    {
        "filename": "02_gsm_ved.ipynb",
        "title": "GSM-VED: Visco-elasto-damage Model",
        "description": "Extended material model combining viscoelasticity with damage mechanics.\n" +
                      "Explores damage evolution under monotonic loading and its coupling with viscous effects.\n" +
                      "Compares elastic control vs. stress control responses."
    },
    {
        "filename": "03_gsm_vevpd_lih.ipynb",
        "title": "GSM-VEVPD-LIH: Visco-elasto-visco-plastic-damage with Linear Isotropic Hardening",
        "description": "Comprehensive material model incorporating viscoelasticity, viscoplasticity, and damage.\n" +
                      "Features linear isotropic hardening and demonstrates complex material responses.\n" +
                      "Suitable for modeling advanced material behaviors under various loading conditions."
    },
    {
        "filename": "04_present_gsm_derivation.ipynb",
        "title": "GSM Framework Derivation and Theory",
        "description": "Theoretical foundation and mathematical derivation of the GSM framework.\n" +
                      "Covers thermodynamic principles, variational formulations, and constitutive equations.\n" +
                      "Essential for understanding the underlying physics and mathematics of GSM models."
    },
    {
        "filename": "05_present_gsm_monotonic_asc.ipynb",
        "title": "GSM under Monotonic Ascending Loading",
        "description": "Detailed analysis of GSM material behavior under monotonic increasing loads.\n" +
                      "Demonstrates stress-strain evolution, internal variable development, and energy dissipation.\n" +
                      "Provides insights into material response characteristics during progressive loading."
    },
    {
        "filename": "06_present_gsm_cyclic_strain.ipynb",
        "title": "GSM under Cyclic Strain Loading",
        "description": "Investigation of GSM material response under cyclic and fatigue loading conditions.\n" +
                      "Explores hysteresis behavior, energy dissipation per cycle, and progressive damage accumulation.\n" +
                      "Critical for understanding material degradation and lifetime prediction."
    }
]

# %%
# Generate formatted markdown content with hyperlinks
markdown_content = "## Notebook Collection\n\n"

for i, notebook in enumerate(notebooks, 1):
    markdown_content += f"### {i}. [{notebook['title']}]({notebook['filename']})\n\n"
    markdown_content += f"{notebook['description']}\n\n"
    markdown_content += "---\n\n"

# Add getting started section
markdown_content += "## Getting Started\n\n"
markdown_content += "**Recommended Order:**\n"
markdown_content += "1. Start with the theoretical background (Notebook 4)\n"
markdown_content += "2. Explore basic models (Notebooks 1-3) in order of increasing complexity\n"
markdown_content += "3. Study specific loading scenarios (Notebooks 5-6)\n\n"
markdown_content += "**Prerequisites:**\n"
markdown_content += "- Basic knowledge of continuum mechanics and material modeling\n"
markdown_content += "- Familiarity with Python and Jupyter notebooks\n"
markdown_content += "- Understanding of thermodynamic principles (helpful but not required)\n\n"
markdown_content += "**Software Requirements:**\n"
markdown_content += "- `bmcs_matmod` package installed\n"
markdown_content += "- Standard scientific Python libraries (numpy, matplotlib, sympy)\n"

print("Generated index content successfully!")

# %%
# Display the formatted index
display(Markdown(markdown_content))

# %% [markdown]
# ## Additional Resources
#
# - **GSM Framework Documentation**: Comprehensive documentation and API reference
# - **BMCS Project**: Visit the [BMCS Group](https://www.bmcs.rw.rwth-aachen.de/) for more research and development updates
# - **Citation**: If you use these notebooks or the GSM framework in your research, please cite the relevant publications
#
# ## Support
#
# For questions, issues, or contributions:
# - GitHub Repository: [bmcs_matmod](https://github.com/bmcs-group/bmcs_matmod)
# - Contact: BMCS Group, RWTH Aachen University
#
# ---
#
# *Last updated: August 2025*
