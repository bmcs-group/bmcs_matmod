# %% [markdown]
# # Derivation of the level set function for SLIDE interface model 3.2

# %% [markdown]
# ![image.png](f_smooth_cap.png)

# %%
# %matplotlib widget
import sympy as sp
import numpy as np
import matplotlib.pylab as plt
from mpl_toolkits.mplot3d import Axes3D
import ipywidgets as ipw
sp.init_printing()
from bmcs_matmod.slide.cymbol import Cymbol, ccode

# %% [markdown]
# # Variables
#
# **Stress variables**
#
# $x$ corresponds to $\sigma_N$ and $y$ corresponds to $\sigma_T$

# %%
x, y = sp.symbols('x, y')

# %% [markdown]
# **Unknown parameters of the ellipse cap function**

# %%
x_c = sp.symbols('x_c') # center point of an ellipse
a = sp.symbols('a', nonnegative=True)
b = sp.symbols('b', nonnegative=True)
c = sp.symbols('c', positive=True)

# %% [markdown]
# **Material parameters**

# %%
x_0 = sp.symbols('x_0')
x_bar, y_bar = sp.symbols(r'\bar{x}, \bar{y}', nonnegative=True )
m = Cymbol(r'm', codename='m_', real=True, nonnegative=True)

# %% [markdown]
# # Mid part of the threshold function

# %% [markdown]
# The linear part of the thresshold function is introduced as
# \begin{align}
# f_\mathrm{lin} :=
# |y| - \bar{y} + m(x - x_0)
# \end{align}
# where $x_0$ denotes the reference position at which $y = \pm \bar{y}$

# %%
f_mid_ = sp.sqrt(y**2) - (y_bar - m * (x-x_0))
get_f_mid = sp.lambdify((x, y, y_bar, m), f_mid_)
f_mid_
# Out:
#                           ____
#                          ╱  2
# m⋅(x - x₀) - \bar{y} + ╲╱  y

# %% [markdown]
# # Cap function
#
# It is introduced in form of an ellipse centered at the position ($x_c, 0$), i.e.
# \begin{align}
# f_\mathrm{ell} := \sqrt{\dfrac{y^2}{b^2} + \dfrac{(x - x_0 - x_\mathrm{c})^2}{a^2}} - c
# \end{align}
# The parameters $a, b, c$ and $x_\mathrm{c}$ are determined based on the compatibility and continuity conditions along the transition between $f_\mathrm{lin}$ and $f_\mathrm{ell}$.

# %%
f_cap_ = sp.sqrt((x-x_0-x_c)**2/a**2 + y**2/b**2) - c
f_cap_
# Out:
#            ______________________
#           ╱  2                 2
#          ╱  y    (x - x₀ - x_c)
# -c +    ╱   ── + ───────────────
#        ╱     2           2
#      ╲╱     b           a

# %% [markdown]
# Construct the derivatives

# %%
df_cap_dx_ = f_cap_.diff(x)
df_cap_dy_ = f_cap_.diff(y)

# %% [markdown]
# # Compatibility and smoothness conditions specified in the figure above

# %% [markdown]
# \begin{align}
# \left. f_\mathrm{ell} \right|_{x = \bar{x}, y = 0} &= 0 \\
# \left. f_\mathrm{ell} \right|_{x=x_0, y=\bar{y}} &= 0 \\
# \left.
# \dfrac{f_{\mathrm{ell},x}}{f_{\mathrm{ell},y}
# }
# \right|_{x=x_\mathrm{c}, y=\bar{y}}
# &= -m
# \end{align}

# %%
eq1 = sp.Eq(f_cap_.subs({x: x_bar, y: 0}), 0)
eq2 = sp.Eq(f_cap_.subs({x: x_0, y: y_bar}), 0)
eq3 = sp.Eq((-df_cap_dx_ / df_cap_dy_).subs({x: x_0, y: y_bar}), -m)
eq1, eq2, eq3
# Out:
# ⎛           _______________________                 _________________
# ⎜          ╱                     2                 ╱        2      2
# ⎜         ╱  (\bar{x} - x₀ - x_c)                 ╱  \bar{y}    x_c          b
# ⎜-c +    ╱   ─────────────────────  = 0, -c +    ╱   ──────── + ────  = 0, ───
# ⎜       ╱               2                       ╱        2        2
# ⎝     ╲╱               a                      ╲╱        b        a         \ba
#
#             ⎞
# 2           ⎟
#  ⋅x_c       ⎟
# ─────── = -m⎟
#       2     ⎟
# r{y}⋅a      ⎠

# %% [markdown]
# Solve for $a, b$ and $x_c$

# %%
abx_subs = sp.solve({eq1, eq2, eq3},{a, b, x_c})[0]
abx_subs
# Out:
# ⎧
# ⎪                                                        _________
# ⎪                                                      ╲╱ \bar{y} ⋅(-m⋅\bar{x}
# ⎨   -(\bar{x} - x₀)⋅(-m⋅\bar{x} + m⋅x₀ + \bar{y})
# ⎪a: ──────────────────────────────────────────────, b: ───────────────────────
# ⎪        c⋅(-2⋅m⋅\bar{x} + 2⋅m⋅x₀ + \bar{y})
# ⎩
#
#                        _________________________________
#                       ╱                1
#  + m⋅x₀ + \bar{y})⋅  ╱  ───────────────────────────────          ⎛       2
#                    ╲╱   -2⋅m⋅\bar{x} + 2⋅m⋅x₀ + \bar{y}        m⋅⎝\bar{x}  - 2
# ────────────────────────────────────────────────────────, x_c: ───────────────
#                 c                                                2⋅m⋅\bar{x} -
#
#
#                   ⎫
#                   ⎪
#                 2⎞⎪
# ⋅\bar{x}⋅x₀ + x₀ ⎠⎬
# ──────────────────⎪
#  2⋅m⋅x₀ - \bar{y} ⎪
#                   ⎭

# %% [markdown]
# # Continuity between $f_\mathrm{mid}$ and $f_\mathrm{cap}$

# %% [markdown]
# **Require an identical value for**
# \begin{align}
# f_\mathrm{mid}(x_c, 0) = f_\mathrm{cap}(x_c,0)
# \end{align}

# %%
f_mid_c_ = f_mid_.subs({x: abx_subs[x_c]+x_0,y:0})
f_cap_abx_ = f_cap_.subs(abx_subs)
f_cap_abxc_ = f_cap_abx_.subs({x: abx_subs[x_c]+x_0,y:0})
eq4 = sp.Eq(f_cap_abxc_, f_mid_c_)
eq4
# Out:
#       2 ⎛       2                    2⎞
#      m ⋅⎝\bar{x}  - 2⋅\bar{x}⋅x₀ + x₀ ⎠
# -c = ────────────────────────────────── - \bar{y}
#        2⋅m⋅\bar{x} - 2⋅m⋅x₀ - \bar{y}

# %% [markdown]
# Which can be used to express $c$

# %%
c_solved = sp.solve(eq4, c)[0]
sp.simplify(c_solved)
# Out:
#  2        2      2               2   2
# m ⋅\bar{x}  - 2⋅m ⋅\bar{x}⋅x₀ + m ⋅x₀  - 2⋅m⋅\bar{x}⋅\bar{y} + 2⋅m⋅\bar{y}⋅x₀
# ──────────────────────────────────────────────────────────────────────────────
#                             -2⋅m⋅\bar{x} + 2⋅m⋅x₀ + \bar{y}
#
#          2
# + \bar{y}
# ──────────

# %% [markdown]
# Substitute back the $f_\mathrm{cap}$ to obtain its resolved form

# %%
f_cap_solved_ = f_cap_abx_.subs(c, c_solved)
f_cap_solved_
# Out:
#          _____________________________________________________________________
#         ╱                                               2
#        ╱  ⎛    ⎛       2                    2⎞         ⎞
#       ╱   ⎜  m⋅⎝\bar{x}  - 2⋅\bar{x}⋅x₀ + x₀ ⎠         ⎟  ⎛ 2        2      2
#      ╱    ⎜- ───────────────────────────────── + x - x₀⎟ ⋅⎝m ⋅\bar{x}  - 2⋅m ⋅
#     ╱     ⎝    2⋅m⋅\bar{x} - 2⋅m⋅x₀ - \bar{y}          ⎠
#    ╱      ────────────────────────────────────────────────────────────────────
#   ╱                                                                    2
# ╲╱                                                       (\bar{x} - x₀) ⋅(-m⋅\
#
# ______________________________________________________________________________
#
#                                                                       2
#               2   2                                                 2⎞
# \bar{x}⋅x₀ + m ⋅x₀  - 2⋅m⋅\bar{x}⋅\bar{y} + 2⋅m⋅\bar{y}⋅x₀ + \bar{y} ⎠     2 ⎛
#                                                                           y ⋅⎝
# ─────────────────────────────────────────────────────────────────────── + ────
#                         2
# bar{x} + m⋅x₀ + \bar{y})
#
# ______________________________________________________________________________
#
#
#
#  2        2      2               2   2
# m ⋅\bar{x}  - 2⋅m ⋅\bar{x}⋅x₀ + m ⋅x₀  - 2⋅m⋅\bar{x}⋅\bar{y} + 2⋅m⋅\bar{y}⋅x₀
# ──────────────────────────────────────────────────────────────────────────────
#
#        \bar{y}⋅(-2⋅m⋅\bar{x} + 2⋅m⋅x₀ + \bar{y})⋅(-m⋅\bar{x} + m⋅x₀ + \bar{y})
#
# _____________
#
#
#            2
#          2⎞      2        2      2               2   2
# + \bar{y} ⎠     m ⋅\bar{x}  - 2⋅m ⋅\bar{x}⋅x₀ + m ⋅x₀  - 2⋅m⋅\bar{x}⋅\bar{y} +
# ────────────  - ──────────────────────────────────────────────────────────────
# 2                                           -2⋅m⋅\bar{x} + 2⋅m⋅x₀ + \bar{y}
#
#
#
#
#
#
#                          2
#  2⋅m⋅\bar{y}⋅x₀ + \bar{y}
# ──────────────────────────

# %%
A = sp.symbols('A')
f_cap_solved_.subs(x,A)
# Out:
#          _____________________________________________________________________
#         ╱                                               2
#        ╱  ⎛    ⎛       2                    2⎞         ⎞
#       ╱   ⎜  m⋅⎝\bar{x}  - 2⋅\bar{x}⋅x₀ + x₀ ⎠         ⎟  ⎛ 2        2      2
#      ╱    ⎜- ───────────────────────────────── + A - x₀⎟ ⋅⎝m ⋅\bar{x}  - 2⋅m ⋅
#     ╱     ⎝    2⋅m⋅\bar{x} - 2⋅m⋅x₀ - \bar{y}          ⎠
#    ╱      ────────────────────────────────────────────────────────────────────
#   ╱                                                                    2
# ╲╱                                                       (\bar{x} - x₀) ⋅(-m⋅\
#
# ______________________________________________________________________________
#
#                                                                       2
#               2   2                                                 2⎞
# \bar{x}⋅x₀ + m ⋅x₀  - 2⋅m⋅\bar{x}⋅\bar{y} + 2⋅m⋅\bar{y}⋅x₀ + \bar{y} ⎠     2 ⎛
#                                                                           y ⋅⎝
# ─────────────────────────────────────────────────────────────────────── + ────
#                         2
# bar{x} + m⋅x₀ + \bar{y})
#
# ______________________________________________________________________________
#
#
#
#  2        2      2               2   2
# m ⋅\bar{x}  - 2⋅m ⋅\bar{x}⋅x₀ + m ⋅x₀  - 2⋅m⋅\bar{x}⋅\bar{y} + 2⋅m⋅\bar{y}⋅x₀
# ──────────────────────────────────────────────────────────────────────────────
#
#        \bar{y}⋅(-2⋅m⋅\bar{x} + 2⋅m⋅x₀ + \bar{y})⋅(-m⋅\bar{x} + m⋅x₀ + \bar{y})
#
# _____________
#
#
#            2
#          2⎞      2        2      2               2   2
# + \bar{y} ⎠     m ⋅\bar{x}  - 2⋅m ⋅\bar{x}⋅x₀ + m ⋅x₀  - 2⋅m⋅\bar{x}⋅\bar{y} +
# ────────────  - ──────────────────────────────────────────────────────────────
# 2                                           -2⋅m⋅\bar{x} + 2⋅m⋅x₀ + \bar{y}
#
#
#
#
#
#
#                          2
#  2⋅m⋅\bar{y}⋅x₀ + \bar{y}
# ──────────────────────────

# %% [markdown]
# # Test the results

# %%
_x_0=-3
_x_bar=-5
_y_bar=3
_m=.3

# %% [markdown]
# The value in the denominator must not be equal to 0

# %%
m_limit_ = sp.solve(2*x_bar * m + y_bar, m)[0]
_m_limit = m_limit_.subs({x_bar: _x_bar, y_bar: _y_bar})
_m_limit
# Out:
# 3/10

# %%
if _m < _m_limit * sp.sign(_x_bar - _x_0):
    print('Take care')

# %% [markdown]
# Test the obtained position of $x_c$

# %%
x_c_ = abx_subs[x_c]
x_c_
# Out:
#   ⎛       2                    2⎞
# m⋅⎝\bar{x}  - 2⋅\bar{x}⋅x₀ + x₀ ⎠
# ─────────────────────────────────
#   2⋅m⋅\bar{x} - 2⋅m⋅x₀ - \bar{y}

# %%
get_x_c = sp.lambdify((x_bar, y_bar, m, x_0), x_c_, 'numpy' )
_x_c = get_x_c(_x_bar, _y_bar, _m, _x_0)
_x_c
# Out:
# -0.2857142857142857

# %% [markdown]
# # Domain separation for $f_\mathrm{cap}$ and $f_\mathrm{mid}$
#
# Define the transition between cap and mid domains by defining a connection
# line between [$x_c$,0]-[0,$\bar{\tau}$].

# %%
(-y_bar / (x_c) * (x - x_0 -x_c))
# Out:
# -\bar{y}⋅(x - x₀ - x_c)
# ────────────────────────
#           x_c

# %%
y_trans_ = (-y_bar / (x_c) * (x - x_0 - x_c)).subs(x_c, x_c_)
f_cap_domain_ = sp.sign(x_bar-x_0) * sp.sign(-m) * (sp.Abs(y) - y_trans_) > 0

# %%
x_trans = np.linspace(_x_c, _x_0, 10)
get_y_trans = sp.lambdify((x, x_bar, y_bar, m, x_0), y_trans_)
y_trans = get_y_trans(x_trans, _x_bar, _y_bar, _m, _x_0)
x_trans, y_trans
# Out:
# (array([-0.28571429, -0.58730159, -0.88888889, -1.19047619, -1.49206349,
#         -1.79365079, -2.0952381 , -2.3968254 , -2.6984127 , -3.        ]),
#  array([31.5       , 28.33333333, 25.16666667, 22.        , 18.83333333,
#         15.66666667, 12.5       ,  9.33333333,  6.16666667,  3.        ]))

# %%
get_y_trans(_x_c, _x_bar, _y_bar, _m, _x_0)
# Out:
# 31.500000000000004

# %% [markdown]
# # Composed smooth level set function $f_\mathrm{full}(x,y)$

# %%
f_full_ = sp.Piecewise(
    (f_cap_solved_, f_cap_domain_),
    (f_mid_, True)
)
get_f_full = sp.lambdify((x, y, x_bar, y_bar, m, x_0), f_full_, 'numpy')
f_full_
# Out:
# ⎧         ____________________________________________________________________
# ⎪        ╱                                               2
# ⎪       ╱  ⎛    ⎛       2                    2⎞         ⎞
# ⎪      ╱   ⎜  m⋅⎝\bar{x}  - 2⋅\bar{x}⋅x₀ + x₀ ⎠         ⎟  ⎛ 2        2      2
# ⎪     ╱    ⎜- ───────────────────────────────── + x - x₀⎟ ⋅⎝m ⋅\bar{x}  - 2⋅m
# ⎪    ╱     ⎝    2⋅m⋅\bar{x} - 2⋅m⋅x₀ - \bar{y}          ⎠
# ⎨   ╱      ───────────────────────────────────────────────────────────────────
# ⎪  ╱                                                                    2
# ⎪╲╱                                                       (\bar{x} - x₀) ⋅(-m⋅
# ⎪
# ⎪
# ⎪
# ⎩
#
# ______________________________________________________________________________
#
#                                                                        2
#                2   2                                                 2⎞
# ⋅\bar{x}⋅x₀ + m ⋅x₀  - 2⋅m⋅\bar{x}⋅\bar{y} + 2⋅m⋅\bar{y}⋅x₀ + \bar{y} ⎠     2
#                                                                            y ⋅
# ──────────────────────────────────────────────────────────────────────── + ───
#                          2
# \bar{x} + m⋅x₀ + \bar{y})
#
#
#
#                                                                              m
#
# ______________________________________________________________________________
#
#
#
# ⎛ 2        2      2               2   2
# ⎝m ⋅\bar{x}  - 2⋅m ⋅\bar{x}⋅x₀ + m ⋅x₀  - 2⋅m⋅\bar{x}⋅\bar{y} + 2⋅m⋅\bar{y}⋅x₀
# ──────────────────────────────────────────────────────────────────────────────
#
#         \bar{y}⋅(-2⋅m⋅\bar{x} + 2⋅m⋅x₀ + \bar{y})⋅(-m⋅\bar{x} + m⋅x₀ + \bar{y}
#
#                          ____
#                         ╱  2
# ⋅(x - x₀) - \bar{y} + ╲╱  y
#
# ______________
#
#
#             2
#           2⎞      2        2      2               2   2
#  + \bar{y} ⎠     m ⋅\bar{x}  - 2⋅m ⋅\bar{x}⋅x₀ + m ⋅x₀  - 2⋅m⋅\bar{x}⋅\bar{y}
# ─────────────  - ─────────────────────────────────────────────────────────────
#  2                                           -2⋅m⋅\bar{x} + 2⋅m⋅x₀ + \bar{y}
# )
#
#
#
#
#
#
#
#                                  ⎛
#                                  ⎜
#                           2      ⎜      \bar{y}⋅(2⋅m⋅\bar{x} - 2⋅m⋅x₀ - \bar{y
# + 2⋅m⋅\bar{y}⋅x₀ + \bar{y}       ⎜
# ───────────────────────────  for ⎜│y│ + ──────────────────────────────────────
#                                  ⎜                                   ⎛       2
#                                  ⎝                                 m⋅⎝\bar{x}
#
#
#
#
#
#
#
#    ⎛    ⎛       2                    2⎞         ⎞⎞
#    ⎜  m⋅⎝\bar{x}  - 2⋅\bar{x}⋅x₀ + x₀ ⎠         ⎟⎟
# })⋅⎜- ───────────────────────────────── + x - x₀⎟⎟
#    ⎝    2⋅m⋅\bar{x} - 2⋅m⋅x₀ - \bar{y}          ⎠⎟
# ─────────────────────────────────────────────────⎟⋅sign(m)⋅sign(\bar{x} - x₀)
#                     2⎞                           ⎟
#  - 2⋅\bar{x}⋅x₀ + x₀ ⎠                           ⎠
#
#
#
#            otherwise
#
#
#
#
#
#
#
# < 0

# %% [markdown]
# # Visualization

# %% [markdown]
# Evaluate the threshold function within an orthogonal grid

# %%
X_a, Y_a = np.mgrid[-10:10:210j, -10:10:210j]
Z_a = get_f_full(X_a, Y_a, _x_bar, _y_bar, _m, _x_0)
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1, 1, 1)
ax.contour(X_a, Y_a, Z_a, levels=8)
ax.plot([_x_0], [_y_bar], marker='o')
ax.plot([_x_bar], [0], marker='o', color='red')
ax.plot([_x_c+_x_0], [0], marker='o', color='green')
ax.set_aspect('equal')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Composed level set function with two caps

# %%
f_t = Cymbol(r'f_\mathrm{t}', codename='f_t_')
f_c = Cymbol(r'f_\mathrm{c}', codename='f_c_')
f_c0 = Cymbol(r'f_\mathrm{c0}', codename='f_c0_')
f_s = Cymbol(r'f_\mathrm{s}', codename='f_s_')

# %%
subs_tension = {x_0: 0, x_bar: f_t, y_bar: f_s}
subs_shear = {y_bar: f_s, x_0: 0}
subs_compression = {x_0: -f_c0, x_bar: -f_c,  y_bar: f_s-m*(-f_c0) }

# %%
f_solved_ = sp.Piecewise(
    (f_cap_solved_.subs(subs_tension), f_cap_domain_.subs(subs_tension)),
    (f_cap_solved_.subs(subs_compression), f_cap_domain_.subs(subs_compression)),
    (f_mid_.subs(subs_shear), True)
)
f_solved_
# Out:
# ⎧
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪         ____________________________________________________________________
# ⎨        ╱
# ⎪       ╱
# ⎪      ╱
# ⎪     ╱     2 ⎛             2  2                                 2
# ⎪    ╱     y ⋅⎝f_\mathrm{c0} ⋅m  - 2⋅f_\mathrm{c0}⋅f_\mathrm{c}⋅m  - 2⋅f_\math
# ⎪   ╱      ───────────────────────────────────────────────────────────────────
# ⎪  ╱
# ⎪╲╱                                                          (f_\mathrm{c0}⋅m
# ⎪
# ⎪
# ⎪
# ⎩
#
#
#
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
#
#
#
#                                                         2  2
# rm{c0}⋅m⋅(f_\mathrm{c0}⋅m + f_\mathrm{s}) + f_\mathrm{c} ⋅m  + 2⋅f_\mathrm{c}⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                                2
# + f_\mathrm{s})⋅(f_\mathrm{c}⋅m + f_\mathrm{s}) ⋅(-f_\mathrm{c0}⋅m + 2⋅f_\math
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
#
#                                                                            ⎛
#                                                                        2   ⎜
#                                                                      2⎞    ⎜f_
# m⋅(f_\mathrm{c0}⋅m + f_\mathrm{s}) + (f_\mathrm{c0}⋅m + f_\mathrm{s}) ⎠    ⎝
# ──────────────────────────────────────────────────────────────────────── + ───
#
# rm{c}⋅m + f_\mathrm{s})
#
#
#
#
#
#                _______________________________________________________________
#               ╱                                         2
#              ╱  ⎛                      2               ⎞
#             ╱   ⎜          f_\mathrm{t} ⋅m             ⎟  ⎛            2
#            ╱    ⎜- ──────────────────────────────── + x⎟ ⋅⎝f_\mathrm{s}  - 2⋅f
#           ╱     ⎝  -f_\mathrm{s} + 2⋅f_\mathrm{t}⋅m    ⎠
#          ╱      ──────────────────────────────────────────────────────────────
#         ╱                                                   2
#       ╲╱                                        f_\mathrm{t} ⋅(f_\mathrm{s} -
#
# ______________________________________________________________________________
#
#                 ⎛             2                                              2
#               m⋅⎝f_\mathrm{c0}  - 2⋅f_\mathrm{c0}⋅f_\mathrm{c} + f_\mathrm{c}
# \mathrm{c0} - ────────────────────────────────────────────────────────────────
#                       f_\mathrm{c0}⋅m - 2⋅f_\mathrm{c}⋅m - f_\mathrm{s}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
# ______________________________________________________________________________
#
#                                               2
#                                          2  2⎞
# _\mathrm{s}⋅f_\mathrm{t}⋅m + f_\mathrm{t} ⋅m ⎠          2 ⎛            2
#                                                        y ⋅⎝f_\mathrm{s}  - 2⋅f
# ─────────────────────────────────────────────── + ────────────────────────────
#                2
# f_\mathrm{t}⋅m)                                   f_\mathrm{s}⋅(f_\mathrm{s} -
#
# ______________________________________________________________________________
#       2
# ⎞    ⎞
# ⎠    ⎟  ⎛             2  2                                 2
# ─ + x⎟ ⋅⎝f_\mathrm{c0} ⋅m  - 2⋅f_\mathrm{c0}⋅f_\mathrm{c}⋅m  - 2⋅f_\mathrm{c0}
#      ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                                                      2
#                                        (f_\mathrm{c0} - f_\mathrm{c}) ⋅(f_\mat
#
#                                                                          ____
#                                                                         ╱  2
#                                                 -f_\mathrm{s} + m⋅x + ╲╱  y
#
# ____________________________________________________
#
#
#                                               2
#                                          2  2⎞                     2
# _\mathrm{s}⋅f_\mathrm{t}⋅m + f_\mathrm{t} ⋅m ⎠         f_\mathrm{s}  - 2⋅f_\ma
# ───────────────────────────────────────────────────  - ───────────────────────
#                                                   2                    f_\math
#  2⋅f_\mathrm{t}⋅m)⋅(f_\mathrm{s} - f_\mathrm{t}⋅m)
#
# ______________________________________________________________________________
#
#
#                                                   2  2
# ⋅m⋅(f_\mathrm{c0}⋅m + f_\mathrm{s}) + f_\mathrm{c} ⋅m  + 2⋅f_\mathrm{c}⋅m⋅(f_\
#
# ──────────────────────────────────────────────────────────────────────────────
#                         2
# hrm{c}⋅m + f_\mathrm{s})
#
#
#
#
#
#
#
#
#
#                                      2  2
# thrm{s}⋅f_\mathrm{t}⋅m + f_\mathrm{t} ⋅m
# ─────────────────────────────────────────
# rm{s} - 2⋅f_\mathrm{t}⋅m
#
#
# ___________________________________________________________________
#
#                                                                  2
#                                                                2⎞
# mathrm{c0}⋅m + f_\mathrm{s}) + (f_\mathrm{c0}⋅m + f_\mathrm{s}) ⎠
#                                                                       f_\mathr
# ──────────────────────────────────────────────────────────────────  - ────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      2  2                                 2
# m{c0} ⋅m  - 2⋅f_\mathrm{c0}⋅f_\mathrm{c}⋅m  - 2⋅f_\mathrm{c0}⋅m⋅(f_\mathrm{c0}
# ──────────────────────────────────────────────────────────────────────────────
#                                                                          -f_\m
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                  2  2
# ⋅m + f_\mathrm{s}) + f_\mathrm{c} ⋅m  + 2⋅f_\mathrm{c}⋅m⋅(f_\mathrm{c0}⋅m + f_
# ──────────────────────────────────────────────────────────────────────────────
# athrm{c0}⋅m + 2⋅f_\mathrm{c}⋅m + f_\mathrm{s}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                      ⎛
#                                                      ⎜
#                                               2      ⎜      (f_\mathrm{c0}⋅m +
# \mathrm{s}) + (f_\mathrm{c0}⋅m + f_\mathrm{s})       ⎜
# ───────────────────────────────────────────────  for ⎜│y│ + ──────────────────
#                                                      ⎜
#                                                      ⎝
#
#
#
#
#
#
#
#                          ⎛                                                ⎛
#                          ⎜                                                ⎜
#                          ⎜f_\mathrm{s}⋅(-f_\mathrm{s} + 2⋅f_\mathrm{t}⋅m)⋅⎜- ─
#                          ⎜                                                ⎝  -
#                      for ⎜────────────────────────────────────────────────────
#                          ⎜                                                2
#                          ⎝                                    f_\mathrm{t} ⋅m
#
#
#
#                ⎛                  ⎛             2
#                ⎜                m⋅⎝f_\mathrm{c0}  - 2⋅f_\mathrm{c0}⋅f_\mathrm{
#  f_\mathrm{s})⋅⎜f_\mathrm{c0} - ──────────────────────────────────────────────
#                ⎝                        f_\mathrm{c0}⋅m - 2⋅f_\mathrm{c}⋅m - f
# ──────────────────────────────────────────────────────────────────────────────
#                                      ⎛             2
#                                    m⋅⎝f_\mathrm{c0}  - 2⋅f_\mathrm{c0}⋅f_\math
#
#
#
#
#
#
#
#                    2               ⎞      ⎞
#        f_\mathrm{t} ⋅m             ⎟      ⎟
# ─────────────────────────────── + x⎟      ⎟
# f_\mathrm{s} + 2⋅f_\mathrm{t}⋅m    ⎠      ⎟
# ──────────────────────────────────── + │y│⎟⋅sign(f_\mathrm{t})⋅sign(m) < 0
#                                           ⎟
#                                           ⎠
#
#
#
#                  2⎞    ⎞                                                    ⎞
# c} + f_\mathrm{c} ⎠    ⎟                                                    ⎟
# ─────────────────── + x⎟⋅(f_\mathrm{c0}⋅m - 2⋅f_\mathrm{c}⋅m - f_\mathrm{s})⎟
# _\mathrm{s}            ⎠                                                    ⎟
# ────────────────────────────────────────────────────────────────────────────⎟⋅
#                     2⎞                                                      ⎟
# rm{c} + f_\mathrm{c} ⎠                                                      ⎠
#
#
#
#     otherwise
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sign(m)⋅sign(f_\mathrm{c0} - f_\mathrm{c}) < 0

# %%
get_f_solved = sp.lambdify((x, y, f_t, f_c, f_c0, f_s, m), f_solved_, 'numpy')

# %%
f_solved_
# Out:
# ⎧
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪         ____________________________________________________________________
# ⎨        ╱
# ⎪       ╱
# ⎪      ╱
# ⎪     ╱     2 ⎛             2  2                                 2
# ⎪    ╱     y ⋅⎝f_\mathrm{c0} ⋅m  - 2⋅f_\mathrm{c0}⋅f_\mathrm{c}⋅m  - 2⋅f_\math
# ⎪   ╱      ───────────────────────────────────────────────────────────────────
# ⎪  ╱
# ⎪╲╱                                                          (f_\mathrm{c0}⋅m
# ⎪
# ⎪
# ⎪
# ⎩
#
#
#
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
#
#
#
#                                                         2  2
# rm{c0}⋅m⋅(f_\mathrm{c0}⋅m + f_\mathrm{s}) + f_\mathrm{c} ⋅m  + 2⋅f_\mathrm{c}⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                                2
# + f_\mathrm{s})⋅(f_\mathrm{c}⋅m + f_\mathrm{s}) ⋅(-f_\mathrm{c0}⋅m + 2⋅f_\math
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
#
#                                                                            ⎛
#                                                                        2   ⎜
#                                                                      2⎞    ⎜f_
# m⋅(f_\mathrm{c0}⋅m + f_\mathrm{s}) + (f_\mathrm{c0}⋅m + f_\mathrm{s}) ⎠    ⎝
# ──────────────────────────────────────────────────────────────────────── + ───
#
# rm{c}⋅m + f_\mathrm{s})
#
#
#
#
#
#                _______________________________________________________________
#               ╱                                         2
#              ╱  ⎛                      2               ⎞
#             ╱   ⎜          f_\mathrm{t} ⋅m             ⎟  ⎛            2
#            ╱    ⎜- ──────────────────────────────── + x⎟ ⋅⎝f_\mathrm{s}  - 2⋅f
#           ╱     ⎝  -f_\mathrm{s} + 2⋅f_\mathrm{t}⋅m    ⎠
#          ╱      ──────────────────────────────────────────────────────────────
#         ╱                                                   2
#       ╲╱                                        f_\mathrm{t} ⋅(f_\mathrm{s} -
#
# ______________________________________________________________________________
#
#                 ⎛             2                                              2
#               m⋅⎝f_\mathrm{c0}  - 2⋅f_\mathrm{c0}⋅f_\mathrm{c} + f_\mathrm{c}
# \mathrm{c0} - ────────────────────────────────────────────────────────────────
#                       f_\mathrm{c0}⋅m - 2⋅f_\mathrm{c}⋅m - f_\mathrm{s}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
# ______________________________________________________________________________
#
#                                               2
#                                          2  2⎞
# _\mathrm{s}⋅f_\mathrm{t}⋅m + f_\mathrm{t} ⋅m ⎠          2 ⎛            2
#                                                        y ⋅⎝f_\mathrm{s}  - 2⋅f
# ─────────────────────────────────────────────── + ────────────────────────────
#                2
# f_\mathrm{t}⋅m)                                   f_\mathrm{s}⋅(f_\mathrm{s} -
#
# ______________________________________________________________________________
#       2
# ⎞    ⎞
# ⎠    ⎟  ⎛             2  2                                 2
# ─ + x⎟ ⋅⎝f_\mathrm{c0} ⋅m  - 2⋅f_\mathrm{c0}⋅f_\mathrm{c}⋅m  - 2⋅f_\mathrm{c0}
#      ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                                                      2
#                                        (f_\mathrm{c0} - f_\mathrm{c}) ⋅(f_\mat
#
#                                                                          ____
#                                                                         ╱  2
#                                                 -f_\mathrm{s} + m⋅x + ╲╱  y
#
# ____________________________________________________
#
#
#                                               2
#                                          2  2⎞                     2
# _\mathrm{s}⋅f_\mathrm{t}⋅m + f_\mathrm{t} ⋅m ⎠         f_\mathrm{s}  - 2⋅f_\ma
# ───────────────────────────────────────────────────  - ───────────────────────
#                                                   2                    f_\math
#  2⋅f_\mathrm{t}⋅m)⋅(f_\mathrm{s} - f_\mathrm{t}⋅m)
#
# ______________________________________________________________________________
#
#
#                                                   2  2
# ⋅m⋅(f_\mathrm{c0}⋅m + f_\mathrm{s}) + f_\mathrm{c} ⋅m  + 2⋅f_\mathrm{c}⋅m⋅(f_\
#
# ──────────────────────────────────────────────────────────────────────────────
#                         2
# hrm{c}⋅m + f_\mathrm{s})
#
#
#
#
#
#
#
#
#
#                                      2  2
# thrm{s}⋅f_\mathrm{t}⋅m + f_\mathrm{t} ⋅m
# ─────────────────────────────────────────
# rm{s} - 2⋅f_\mathrm{t}⋅m
#
#
# ___________________________________________________________________
#
#                                                                  2
#                                                                2⎞
# mathrm{c0}⋅m + f_\mathrm{s}) + (f_\mathrm{c0}⋅m + f_\mathrm{s}) ⎠
#                                                                       f_\mathr
# ──────────────────────────────────────────────────────────────────  - ────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      2  2                                 2
# m{c0} ⋅m  - 2⋅f_\mathrm{c0}⋅f_\mathrm{c}⋅m  - 2⋅f_\mathrm{c0}⋅m⋅(f_\mathrm{c0}
# ──────────────────────────────────────────────────────────────────────────────
#                                                                          -f_\m
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                  2  2
# ⋅m + f_\mathrm{s}) + f_\mathrm{c} ⋅m  + 2⋅f_\mathrm{c}⋅m⋅(f_\mathrm{c0}⋅m + f_
# ──────────────────────────────────────────────────────────────────────────────
# athrm{c0}⋅m + 2⋅f_\mathrm{c}⋅m + f_\mathrm{s}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                      ⎛
#                                                      ⎜
#                                               2      ⎜      (f_\mathrm{c0}⋅m +
# \mathrm{s}) + (f_\mathrm{c0}⋅m + f_\mathrm{s})       ⎜
# ───────────────────────────────────────────────  for ⎜│y│ + ──────────────────
#                                                      ⎜
#                                                      ⎝
#
#
#
#
#
#
#
#                          ⎛                                                ⎛
#                          ⎜                                                ⎜
#                          ⎜f_\mathrm{s}⋅(-f_\mathrm{s} + 2⋅f_\mathrm{t}⋅m)⋅⎜- ─
#                          ⎜                                                ⎝  -
#                      for ⎜────────────────────────────────────────────────────
#                          ⎜                                                2
#                          ⎝                                    f_\mathrm{t} ⋅m
#
#
#
#                ⎛                  ⎛             2
#                ⎜                m⋅⎝f_\mathrm{c0}  - 2⋅f_\mathrm{c0}⋅f_\mathrm{
#  f_\mathrm{s})⋅⎜f_\mathrm{c0} - ──────────────────────────────────────────────
#                ⎝                        f_\mathrm{c0}⋅m - 2⋅f_\mathrm{c}⋅m - f
# ──────────────────────────────────────────────────────────────────────────────
#                                      ⎛             2
#                                    m⋅⎝f_\mathrm{c0}  - 2⋅f_\mathrm{c0}⋅f_\math
#
#
#
#
#
#
#
#                    2               ⎞      ⎞
#        f_\mathrm{t} ⋅m             ⎟      ⎟
# ─────────────────────────────── + x⎟      ⎟
# f_\mathrm{s} + 2⋅f_\mathrm{t}⋅m    ⎠      ⎟
# ──────────────────────────────────── + │y│⎟⋅sign(f_\mathrm{t})⋅sign(m) < 0
#                                           ⎟
#                                           ⎠
#
#
#
#                  2⎞    ⎞                                                    ⎞
# c} + f_\mathrm{c} ⎠    ⎟                                                    ⎟
# ─────────────────── + x⎟⋅(f_\mathrm{c0}⋅m - 2⋅f_\mathrm{c}⋅m - f_\mathrm{s})⎟
# _\mathrm{s}            ⎠                                                    ⎟
# ────────────────────────────────────────────────────────────────────────────⎟⋅
#                     2⎞                                                      ⎟
# rm{c} + f_\mathrm{c} ⎠                                                      ⎠
#
#
#
#     otherwise
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sign(m)⋅sign(f_\mathrm{c0} - f_\mathrm{c}) < 0

# %%
X_a, Y_a = np.mgrid[-100:20:210j,-30:30:210j]
mp = {'f_t_': 5, 'f_c_': 80, 'f_c0_': 70, 'f_s_': 5, 'm_': 0.1}
Z_a = get_f_solved(X_a,Y_a,**mp)

# %%
fig = plt.figure(figsize=(8,4))
ax = fig.add_subplot(1, 1, 1)
ax.contour(X_a,Y_a,Z_a, levels=8)
ax.plot([_x_0], [_y_bar], marker='o')
ax.plot([_x_bar], [0], marker='o', color='red')
ax.plot([_x_c+_x_0], [0], marker='o', color='green')
ax.set_aspect('equal')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
